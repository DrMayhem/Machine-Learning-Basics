# %%
import pandas as pd

# %%
data = pd.read_csv("fuel price.csv")

# %%
data.head()
# Out:
#    Unnamed: 0        Date  Pump price in pence/litre (ULSP)  \
# 0           2  09/06/2003                             74.59
# 1           3  16/06/2003                             74.47
# 2           4  23/06/2003                             74.42
# 3           5  30/06/2003                             74.35
# 4           6  07/07/2003                             74.28
#
#    Pump price in pence/litre (ULSD)  Duty rate in pence/litre (ULSP)  \
# 0                             76.77                            45.82
# 1                             76.69                            45.82
# 2                             76.62                            45.82
# 3                             76.51                            45.82
# 4                             76.46                            45.82
#
#    Duty rate in pence/litre (ULSD)  VAT percentage rate (ULSP)  \
# 0                            45.82                        17.5
# 1                            45.82                        17.5
# 2                            45.82                        17.5
# 3                            45.82                        17.5
# 4                            45.82                        17.5
#
#    VAT percentage rate (ULSD)
# 0                        17.5
# 1                        17.5
# 2                        17.5
# 3                        17.5
# 4                        17.5

# %%
data.tail()
# Out:
#      Unnamed: 0        Date  Pump price in pence/litre (ULSP)  \
# 904         906  05/10/2020                            113.26
# 905         907  12/10/2020                            113.19
# 906         908  19/10/2020                            113.18
# 907         909  26/10/2020                            113.14
# 908         910  02/11/2020                            113.11
#
#      Pump price in pence/litre (ULSD)  Duty rate in pence/litre (ULSP)  \
# 904                            118.11                            57.95
# 905                            118.05                            57.95
# 906                            118.08                            57.95
# 907                            118.08                            57.95
# 908                            118.06                            57.95
#
#      Duty rate in pence/litre (ULSD)  VAT percentage rate (ULSP)  \
# 904                            57.95                        20.0
# 905                            57.95                        20.0
# 906                            57.95                        20.0
# 907                            57.95                        20.0
# 908                            57.95                        20.0
#
#      VAT percentage rate (ULSD)
# 904                        20.0
# 905                        20.0
# 906                        20.0
# 907                        20.0
# 908                        20.0

# %%
display(data)
# Out:
#      Unnamed: 0        Date  Pump price in pence/litre (ULSP)  \
# 0             2  09/06/2003                             74.59
# 1             3  16/06/2003                             74.47
# 2             4  23/06/2003                             74.42
# 3             5  30/06/2003                             74.35
# 4             6  07/07/2003                             74.28
# ..          ...         ...                               ...
# 904         906  05/10/2020                            113.26
# 905         907  12/10/2020                            113.19
# 906         908  19/10/2020                            113.18
# 907         909  26/10/2020                            113.14
# 908         910  02/11/2020                            113.11
#
#      Pump price in pence/litre (ULSD)  Duty rate in pence/litre (ULSP)  \
# 0                               76.77                            45.82
# 1                               76.69                            45.82
# 2                               76.62                            45.82
# 3                               76.51                            45.82
# 4                               76.46                            45.82
# ..                                ...                              ...
# 904                            118.11                            57.95
# 905                            118.05                            57.95
# 906                            118.08                            57.95
# 907                            118.08                            57.95
# 908                            118.06                            57.95
#
#      Duty rate in pence/litre (ULSD)  VAT percentage rate (ULSP)  \
# 0                              45.82                        17.5
# 1                              45.82                        17.5
# 2                              45.82                        17.5
# 3                              45.82                        17.5
# 4                              45.82                        17.5
# ..                               ...                         ...
# 904                            57.95                        20.0
# 905                            57.95                        20.0
# 906                            57.95                        20.0
# 907                            57.95                        20.0
# 908                            57.95                        20.0
#
#      VAT percentage rate (ULSD)
# 0                          17.5
# 1                          17.5
# 2                          17.5
# 3                          17.5
# 4                          17.5
# ..                          ...
# 904                        20.0
# 905                        20.0
# 906                        20.0
# 907                        20.0
# 908                        20.0
#
# [909 rows x 8 columns]

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
data.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0        Date  Pump price in pence/litre (ULSP)  \
# 0             2  09/06/2003                             74.59
# 1             3  16/06/2003                             74.47
# 2             4  23/06/2003                             74.42
# 3             5  30/06/2003                             74.35
# 4             6  07/07/2003                             74.28
# ..          ...         ...                               ...
# 904         906  05/10/2020                            113.26
# 905         907  12/10/2020                            113.19
# 906         908  19/10/2020                            113.18
# 907         909  26/10/2020                            113.14
# 908         910  02/11/2020                            113.11
#
#      Pump price in pence/litre (ULSD)  Duty rate in pence/litre (ULSP)  \
# 0                               76.77                            45.82
# 1                               76.69                            45.82
# 2                               76.62                            45.82
# 3                               76.51                            45.82
# 4                               76.46                            45.82
# ..                                ...                              ...
# 904                            118.11                            57.95
# 905                            118.05                            57.95
# 906                            118.08                            57.95
# 907                            118.08                            57.95
# 908                            118.06                            57.95
#
#      Duty rate in pence/litre (ULSD)  VAT percentage rate (ULSP)  \
# 0                              45.82                        17.5
# 1                              45.82                        17.5
# 2                              45.82                        17.5
# 3                              45.82                        17.5
# 4                              45.82                        17.5
# ..                               ...                         ...
# 904                            57.95                        20.0
# 905                            57.95                        20.0
# 906                            57.95                        20.0
# 907                            57.95                        20.0
# 908                            57.95                        20.0
#
#      VAT percentage rate (ULSD)
# 0                          17.5
# 1                          17.5
# 2                          17.5
# 3                          17.5
# 4                          17.5
# ..                          ...
# 904                        20.0
# 905                        20.0
# 906                        20.0
# 907                        20.0
# 908                        20.0
#
# [909 rows x 8 columns]>

# %%
data
# Out:
#      Unnamed: 0        Date  Pump price in pence/litre (ULSP)  \
# 0             2  09/06/2003                             74.59
# 1             3  16/06/2003                             74.47
# 2             4  23/06/2003                             74.42
# 3             5  30/06/2003                             74.35
# 4             6  07/07/2003                             74.28
# ..          ...         ...                               ...
# 904         906  05/10/2020                            113.26
# 905         907  12/10/2020                            113.19
# 906         908  19/10/2020                            113.18
# 907         909  26/10/2020                            113.14
# 908         910  02/11/2020                            113.11
#
#      Pump price in pence/litre (ULSD)  Duty rate in pence/litre (ULSP)  \
# 0                               76.77                            45.82
# 1                               76.69                            45.82
# 2                               76.62                            45.82
# 3                               76.51                            45.82
# 4                               76.46                            45.82
# ..                                ...                              ...
# 904                            118.11                            57.95
# 905                            118.05                            57.95
# 906                            118.08                            57.95
# 907                            118.08                            57.95
# 908                            118.06                            57.95
#
#      Duty rate in pence/litre (ULSD)  VAT percentage rate (ULSP)  \
# 0                              45.82                        17.5
# 1                              45.82                        17.5
# 2                              45.82                        17.5
# 3                              45.82                        17.5
# 4                              45.82                        17.5
# ..                               ...                         ...
# 904                            57.95                        20.0
# 905                            57.95                        20.0
# 906                            57.95                        20.0
# 907                            57.95                        20.0
# 908                            57.95                        20.0
#
#      VAT percentage rate (ULSD)
# 0                          17.5
# 1                          17.5
# 2                          17.5
# 3                          17.5
# 4                          17.5
# ..                          ...
# 904                        20.0
# 905                        20.0
# 906                        20.0
# 907                        20.0
# 908                        20.0
#
# [909 rows x 8 columns]

# %%
#PREPROCESSING

# %%
def preprocess_inputs(df):
    df = df.copy()
    
    # Drop index column
    df = df.drop('Unnamed: 0', axis=1)
     # Generate date columns
    df['Date'] = pd.to_datetime(df['Date'])
    
    df['Year'] = df['Date'].apply(lambda x: x.year)
    df['Month'] = df['Date'].apply(lambda x: x.month)
    df['Day'] = df['Date'].apply(lambda x: x.day)
    
    df = df.drop('Date', axis=1)
    
    # Create labels from the Year column
    df['Year'] = df['Year'].apply(lambda x: 1 if x >= 2012 else 0)
    
    # Split df into X and y
    y = df['Year'].copy()
    X = df.drop('Year', axis=1).copy()
    
    # Scale X with a standard scaler
    scaler = StandardScaler()
    X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
    
    return X, y

# %%
X, y = preprocess_inputs(data)

# %%
X
# Out:
#      Pump price in pence/litre (ULSP)  Pump price in pence/litre (ULSD)  \
# 0                           -1.994782                         -2.002815
# 1                           -2.001340                         -2.006938
# 2                           -2.004073                         -2.010545
# 3                           -2.007898                         -2.016215
# 4                           -2.011724                         -2.018791
# ..                                ...                               ...
# 904                          0.118560                          0.127729
# 905                          0.114735                          0.124636
# 906                          0.114188                          0.126183
# 907                          0.112002                          0.126183
# 908                          0.110363                          0.125152
#
#      Duty rate in pence/litre (ULSP)  Duty rate in pence/litre (ULSD)  \
# 0                          -1.866717                        -1.866717
# 1                          -1.866717                        -1.866717
# 2                          -1.866717                        -1.866717
# 3                          -1.866717                        -1.866717
# 4                          -1.866717                        -1.866717
# ..                               ...                              ...
# 904                         0.735037                         0.735037
# 905                         0.735037                         0.735037
# 906                         0.735037                         0.735037
# 907                         0.735037                         0.735037
# 908                         0.735037                         0.735037
#
#      VAT percentage rate (ULSP)  VAT percentage rate (ULSD)     Month  \
# 0                     -0.818744                   -0.818744  0.716806
# 1                     -0.818744                   -0.818744 -0.158185
# 2                     -0.818744                   -0.818744 -0.158185
# 3                     -0.818744                   -0.818744 -0.158185
# 4                     -0.818744                   -0.818744  0.133479
# ..                          ...                         ...       ...
# 904                    0.813358                    0.813358 -0.449848
# 905                    0.813358                    0.813358  1.591796
# 906                    0.813358                    0.813358  1.008469
# 907                    0.813358                    0.813358  1.008469
# 908                    0.813358                    0.813358 -1.324839
#
#           Day
# 0   -1.113329
# 1    0.025944
# 2    0.823435
# 3    1.620926
# 4   -0.999402
# ..        ...
# 904 -0.657620
# 905 -0.657620
# 906  0.367726
# 907  1.165217
# 908 -0.543693
#
# [909 rows x 8 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 904    1
# 905    1
# 906    1
# 907    1
# 908    1
# Name: Year, Length: 909, dtype: int64

# %%
y.value_counts()
# Out:
# 1    462
# 0    447
# Name: Year, dtype: int64

# %%
#Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=123)

# %%
models = {
    "   Logistic Regression": LogisticRegression(),
    "Support Vector Machine": SVC(),
    "         Decision Tree": DecisionTreeClassifier(),
    "        Neural Network": MLPClassifier(),
    "   K-Nearest Neighbors": KNeighborsClassifier(),
    "     Gradient Boosting": GradientBoostingClassifier(),
    "         Random Forest": RandomForestClassifier(),
    "              AdaBoost": AdaBoostClassifier()
}

# %%
for model in models.values():
    model.fit(X_train, y_train)
# Out:
# C:\Users\Umansh Agarwal\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
print("Model Test Accuracies:\n----------------------")

for name, model in models.items():
    print(name + ": {:.2f}%".format(model.score(X_test, y_test) * 100))
# Out:
# Model Test Accuracies:
# ----------------------
#    Logistic Regression: 97.07%
# Support Vector Machine: 97.07%
#          Decision Tree: 97.80%
#         Neural Network: 97.07%
#    K-Nearest Neighbors: 94.51%
#      Gradient Boosting: 95.97%
#          Random Forest: 96.34%
#               AdaBoost: 95.97%
